# %%
import pandas as pd

# %%
circuitos = pd.read_csv("../circuits/circuitosFinal.csv")
circuitos
# Out:
#                        circuitName Location/country desgaste  vueltas_totales  \
# 0   Albert Park Grand Prix Circuit        Australia     Bajo               58
# 1          Circuit of the Americas              USA     Alto               56
# 2    Bahrain International Circuit          Bahrain     Alto               57
# 3                Baku City Circuit       Azerbaijan     Bajo               51
# 4   Circuit de Barcelona-Catalunya            Spain     Alto               66
# 5                      Hungaroring          Hungary     Bajo               70
# 6    Autodromo Enzo e Dino Ferrari            Italy    Medio               63
# 7       Autódromo José Carlos Pace           Brazil    Medio               71
# 8          Jeddah Corniche Circuit     Saudi Arabia     Bajo               50
# 9        Marina Bay Street Circuit        Singapore     Bajo               61
# 10   Miami International Autodrome              USA     Bajo               57
# ...

# %%
pip install requests
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
response = requests.get("http://ergast.com/api/f1/2022/1/pitstops.json")

# %%
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2022/1/pitstops.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '58',
#   'RaceTable': {'season': '2022',
#    'round': '1',
#    'Races': [{'season': '2022',
#      'round': '1',
#      'url': 'http://en.wikipedia.org/wiki/2022_Bahrain_Grand_Prix',
#      'raceName': 'Bahrain Grand Prix',
#      'Circuit': {'circuitId': 'bahrain',
#       'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#       'circuitName': 'Bahrain International Circuit',
#       'Location': {'lat': '26.0325',
#        'long': '50.5106',
#        'locality': 'Sakhir',
#        'country': 'Bahrain'}},
#      'date': '2022-03-20',
#      'time': '15:00:00Z',
#      'PitStops': [{'driverId': 'hamilton',
#        'lap': '11',
#        'stop': '1',
#        'time': '18:21:54',
#        'duration': '25.201'},
#       {'driverId': 'alonso',
#        'lap': '11',
#        'stop': '1',
# ...
