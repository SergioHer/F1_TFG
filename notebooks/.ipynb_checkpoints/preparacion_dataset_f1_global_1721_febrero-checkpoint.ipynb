# %%
import fastf1
import pandas as pd
import numpy as np

# %%
#Obtención de todos los circuitos en csv

circuitos = pd.read_csv("../circuits/circuits_2022.csv")
circuitos
# Out:
#         circuitId                                                url  \
# 0     albert_park  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1        americas  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
# 2         bahrain  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3            baku     http://en.wikipedia.org/wiki/Baku_City_Circuit
# 4       catalunya  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 5     hungaroring           http://en.wikipedia.org/wiki/Hungaroring
# 6           imola  http://en.wikipedia.org/wiki/Autodromo_Enzo_e_...
# 7      interlagos  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 8          jeddah  http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 9      marina_bay  http://en.wikipedia.org/wiki/Marina_Bay_Street...
# 10          miami  http://en.wikipedia.org/wiki/Miami_Internation...
# 11         monaco     http://en.wikipedia.org/wiki/Circuit_de_Monaco
# 12          monza  http://en.wikipedia.org/wiki/Autodromo_Naziona...
# 13  red_bull_ring         http://en.wikipedia.org/wiki/Red_Bull_Ring
# 14         ricard   http://en.wikipedia.org/wiki/Paul_Ricard_Circuit
# 15      rodriguez  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_He...
# 16    silverstone   http://en.wikipedia.org/wiki/Silverstone_Circuit
# 17            spa  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 18         suzuka        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 19     villeneuve  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 20     yas_marina    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 21      zandvoort     http://en.wikipedia.org/wiki/Circuit_Zandvoort
#
#                        circuitName  Location/lat  Location/long  \
# 0   Albert Park Grand Prix Circuit      -37.8497      144.96800
# 1          Circuit of the Americas       30.1328      -97.64110
# 2    Bahrain International Circuit       26.0325       50.51060
# 3                Baku City Circuit       40.3725       49.85330
# 4   Circuit de Barcelona-Catalunya       41.5700        2.26111
# 5                      Hungaroring       47.5789       19.24860
# 6    Autodromo Enzo e Dino Ferrari       44.3439       11.71670
# 7       Autódromo José Carlos Pace      -23.7036      -46.69970
# 8          Jeddah Corniche Circuit       21.6319       39.10440
# 9        Marina Bay Street Circuit        1.2914      103.86400
# 10   Miami International Autodrome       25.9581      -80.23890
# 11               Circuit de Monaco       43.7347        7.42056
# 12    Autodromo Nazionale di Monza       45.6156        9.28111
# 13                   Red Bull Ring       47.2197       14.76470
# 14             Circuit Paul Ricard       43.2506        5.79167
# 15    Autódromo Hermanos Rodríguez       19.4042      -99.09070
# 16             Silverstone Circuit       52.0786       -1.01694
# 17    Circuit de Spa-Francorchamps       50.4372        5.97139
# 18                  Suzuka Circuit       34.8431      136.54100
# 19       Circuit Gilles Villeneuve       45.5000      -73.52280
# 20              Yas Marina Circuit       24.4672       54.60310
# 21          Circuit Park Zandvoort       52.3888        4.54092
#
#    Location/locality Location/country
# 0          Melbourne        Australia
# 1             Austin              USA
# 2             Sakhir          Bahrain
# 3               Baku       Azerbaijan
# 4           Montmeló            Spain
# 5           Budapest          Hungary
# 6              Imola            Italy
# 7          São Paulo           Brazil
# 8             Jeddah     Saudi Arabia
# 9         Marina Bay        Singapore
# 10             Miami              USA
# 11       Monte-Carlo           Monaco
# 12             Monza            Italy
# 13         Spielberg          Austria
# 14      Le Castellet           France
# 15       Mexico City           Mexico
# 16       Silverstone               UK
# 17               Spa          Belgium
# 18            Suzuka            Japan
# 19          Montreal           Canada
# 20         Abu Dhabi              UAE
# 21         Zandvoort      Netherlands

# %%
#Limpiamos el dataframe de circuitos
print("Circuitos disponibles: ")
circuitos = circuitos.drop(['url', 'Location/lat', 'Location/long', 'Location/locality'], axis = 1)
print(circuitos['Location/country'].to_string(index=False))
nombreCircuito = input("Introduce el pais de un Gran Premio: ")
anyoGp = 2020
# Out:
# Circuitos disponibles:
#    Australia
#          USA
#      Bahrain
#   Azerbaijan
#        Spain
#      Hungary
#        Italy
#       Brazil
# Saudi Arabia
#    Singapore
#          USA
#       Monaco
#        Italy
#      Austria
#       France
#       Mexico
#           UK
#      Belgium
#        Japan
#       Canada
#          UAE
#  Netherlands
# Introduce el pais de un Gran Premio: Italy

# %%
#Creamos un nuevo dataframe con el nombre, la localidad y el nivel de desgaste que pueden tener los neumaticos
circuitos_desgaste = circuitos.drop(['circuitId'], axis=1)
circuitos_desgaste
# Out:
#                        circuitName Location/country
# 0   Albert Park Grand Prix Circuit        Australia
# 1          Circuit of the Americas              USA
# 2    Bahrain International Circuit          Bahrain
# 3                Baku City Circuit       Azerbaijan
# 4   Circuit de Barcelona-Catalunya            Spain
# 5                      Hungaroring          Hungary
# 6    Autodromo Enzo e Dino Ferrari            Italy
# 7       Autódromo José Carlos Pace           Brazil
# 8          Jeddah Corniche Circuit     Saudi Arabia
# 9        Marina Bay Street Circuit        Singapore
# 10   Miami International Autodrome              USA
# 11               Circuit de Monaco           Monaco
# 12    Autodromo Nazionale di Monza            Italy
# 13                   Red Bull Ring          Austria
# 14             Circuit Paul Ricard           France
# 15    Autódromo Hermanos Rodríguez           Mexico
# 16             Silverstone Circuit               UK
# 17    Circuit de Spa-Francorchamps          Belgium
# 18                  Suzuka Circuit            Japan
# 19       Circuit Gilles Villeneuve           Canada
# 20              Yas Marina Circuit              UAE
# 21          Circuit Park Zandvoort      Netherlands

# %%
#Creamos una lista con el nivel de desgaste, fuente PIRELLI F1 2022
desgaste = ['Bajo', 'Alto', 'Alto', 'Bajo', 'Alto', 'Bajo', 'Medio', 'Medio', 'Bajo', 'Bajo', 'Bajo', 'Medio', 'Medio', 'Medio', 'Medio', 'Bajo', 'Medio', 'Alto', 'Medio', 'Bajo', 'Medio', 'Medio']
circuitos_desgaste['desgaste'] = desgaste
circuitos_desgaste
vueltas_circuito = ['58', '56', '57', '51', '66', '70', '63', '71', '50', '61', '57', '78', '53', '71', '53', '71', '52', '44', '53', '70', '58', '72']
circuitos_desgaste['vueltas_totales'] = vueltas_circuito
circuitos_desgaste
km_circuito = ['307.574', '308.405', '308.238', '306.049', '307.104', '306.630', '309.049', '305.879', '308.450', '308.706', '308.326', '260.286', '306.720', '306.452', '309.690', '305.354', '306.198', '308.052', '307.471', '305.270', '305.355', '306.648']
circuitos_desgaste['km_total'] = km_circuito
circuitos_desgaste

#Vamos a sacarlo en un csv
#circuitos_desgaste.to_csv("../circuits/circuitosFinal.csv", index=False)
# Out:
#                        circuitName Location/country desgaste vueltas_totales  \
# 0   Albert Park Grand Prix Circuit        Australia     Bajo              58
# 1          Circuit of the Americas              USA     Alto              56
# 2    Bahrain International Circuit          Bahrain     Alto              57
# 3                Baku City Circuit       Azerbaijan     Bajo              51
# 4   Circuit de Barcelona-Catalunya            Spain     Alto              66
# 5                      Hungaroring          Hungary     Bajo              70
# 6    Autodromo Enzo e Dino Ferrari            Italy    Medio              63
# 7       Autódromo José Carlos Pace           Brazil    Medio              71
# 8          Jeddah Corniche Circuit     Saudi Arabia     Bajo              50
# 9        Marina Bay Street Circuit        Singapore     Bajo              61
# 10   Miami International Autodrome              USA     Bajo              57
# 11               Circuit de Monaco           Monaco    Medio              78
# 12    Autodromo Nazionale di Monza            Italy    Medio              53
# 13                   Red Bull Ring          Austria    Medio              71
# 14             Circuit Paul Ricard           France    Medio              53
# 15    Autódromo Hermanos Rodríguez           Mexico     Bajo              71
# 16             Silverstone Circuit               UK    Medio              52
# 17    Circuit de Spa-Francorchamps          Belgium     Alto              44
# 18                  Suzuka Circuit            Japan    Medio              53
# 19       Circuit Gilles Villeneuve           Canada     Bajo              70
# 20              Yas Marina Circuit              UAE    Medio              58
# 21          Circuit Park Zandvoort      Netherlands    Medio              72
#
#    km_total
# 0   307.574
# 1   308.405
# 2   308.238
# 3   306.049
# 4   307.104
# 5   306.630
# 6   309.049
# 7   305.879
# 8   308.450
# 9   308.706
# 10  308.326
# 11  260.286
# 12  306.720
# 13  306.452
# 14  309.690
# 15  305.354
# 16  306.198
# 17  308.052
# 18  307.471
# 19  305.270
# 20  305.355
# 21  306.648

# %%
#Vamos entonces a crear un dataframe para un piloto en una determinada 
#carrera, por ejemplo, Fernando Alonso y Monaco 2022
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) #Omitimos los future warning

fastf1.Cache.enable_cache('../cache') # Para cachear los datos y no tener que bajarlos todo el tiempo

#A continuacion, nos guardamos la sesión en una variable de tipo sesion

race = fastf1.get_session(anyoGp, nombreCircuito, 'R')
race.load(weather=True, telemetry= True)
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Race [v2.3.0]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# api            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '55', '18', '4', '77', '3', '44', '31', '26', '11', '6', '8', '7', '63', '23', '99', '33', '16', '20', '5']

# %%
print("Pilotos disponibles: ")
race.results['Abbreviation']
print(race.results['Abbreviation'].to_string(index=False))
nombrePiloto = input("Introduce un piloto: ")
# Out:
# Pilotos disponibles:
# GAS
# SAI
# STR
# NOR
# BOT
# RIC
# HAM
# OCO
# KVY
# PER
# LAT
# GRO
# RAI
# RUS
# ALB
# GIO
# VER
# LEC
# MAG
# VET
# Introduce un piloto: LEC

# %%
#Creamos un diccionario para tener los nombres de los pilotos en Ergast y en FastF1 (para poder sacar la posicion por cada vuelta)
#ya que la api tiene la pinta del valor y fastf1 tiene la pinta de la clave (en el diccionario)
pilotosDic = {"HAM":"hamilton", "VER":"max_verstappen", "BOT": "bottas", "NOR":"norris", "PER":"perez", "LEC":"leclerc",
             "RIC":"ricciardo", "SAI":"sainz", "TSU":"tsunoda", "STR":"stroll", "RAI":"raikkonen", "GIO":"giovinazi",
              "OCO":"ocon", "RUS":"russel", "VET":"vettel", "MSC":"mick_schumacher", "GAS":"GASLY", "LAT":"latifi",
             "ALO":"alonso", "MAZ":"mazepin"}
print(pilotosDic[nombrePiloto])
# Out:
# leclerc

# %%
#Nos interesa saber el numero de vueltas que dio Alonso en Barcelona 2022


laps_race_pilot = race.laps.pick_driver(nombrePiloto)
weather = race.weather_data # Cogemos tambien el tiempo que hizo al inicio de la carrera
weather
# Out:
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 0   0 days 00:00:33.270000     27.8      40.0     991.4     False       45.2
# 1   0 days 00:01:33.271000     28.0      39.0     991.4     False       45.1
# 2   0 days 00:02:33.287000     27.8      39.5     991.5     False       44.8
# 3   0 days 00:03:33.288000     27.5      40.4     991.4     False       44.3
# 4   0 days 00:04:33.288000     27.6      40.8     991.5     False       44.3
# ..                     ...      ...       ...       ...       ...        ...
# 138 0 days 02:18:33.642000     27.8      41.9     990.4     False       36.2
# 139 0 days 02:19:33.642000     27.8      41.9     990.3     False       36.2
# 140 0 days 02:20:33.648000     27.7      41.9     990.3     False       36.2
# 141 0 days 02:21:33.643000     27.6      42.0     990.4     False       36.1
# 142 0 days 02:22:33.646000     27.6      42.3     990.3     False       35.8
#
#      WindDirection  WindSpeed
# 0              199        2.3
# 1              159        2.5
# 2              233        1.4
# 3              151        0.7
# 4              167        1.1
# ..             ...        ...
# 138            169        1.4
# 139            198        2.0
# 140            158        1.8
# 141            162        1.6
# 142            169        1.7
#
# [143 rows x 8 columns]

# %%
laps_race_pilot
# Out:
#                       Time DriverNumber                LapTime  LapNumber  \
# 878 0 days 00:35:02.290000           16                    NaT          1
# 879 0 days 00:36:30.293000           16 0 days 00:01:28.003000          2
# 880 0 days 00:37:57.218000           16 0 days 00:01:26.925000          3
# 881 0 days 00:39:23.841000           16 0 days 00:01:26.623000          4
# 882 0 days 00:40:50.195000           16 0 days 00:01:26.354000          5
# 883 0 days 00:42:16.740000           16 0 days 00:01:26.545000          6
# 884 0 days 00:43:43.267000           16 0 days 00:01:26.527000          7
# 885 0 days 00:45:09.890000           16 0 days 00:01:26.623000          8
# 886 0 days 00:46:36.642000           16 0 days 00:01:26.752000          9
# 887 0 days 00:48:03.047000           16 0 days 00:01:26.405000         10
# 888 0 days 00:49:29.456000           16 0 days 00:01:26.409000         11
# 889 0 days 00:50:55.833000           16 0 days 00:01:26.377000         12
# 893 0 days 00:56:42.599000 0 days 00:01:26.779000         16     SOFT
# 894 0 days 00:58:15.929000 0 days 00:01:33.330000         17     SOFT
# 895 0 days 01:00:03.340000 0 days 00:01:47.411000         18     HARD
# 896 0 days 01:01:29.366000 0 days 00:01:26.026000         19     HARD
# 897 0 days 01:03:25.299000 0 days 00:01:55.933000         20     HARD
# 898 0 days 01:05:22.705000 0 days 00:01:57.406000         21     HARD
# 899 0 days 01:07:00.319000 0 days 00:01:37.614000         22     HARD
# 900 0 days 01:08:55.897000 0 days 00:01:55.578000         23     HARD
# 901 0 days 01:27:17.699000                    NaT         24     HARD
#
#      TyreLife FreshTyre TrackStatus  Stint              PitInTime
# 878       1.0      True           1      1                    NaT
# 879       2.0      True           1      1                    NaT
# 880       3.0      True           1      1                    NaT
# 881       4.0      True           1      1                    NaT
# 882       5.0      True           1      1                    NaT
# 883       6.0      True           1      1                    NaT
# 884       7.0      True           1      1                    NaT
# 885       8.0      True           2      1                    NaT
# 886       9.0      True           1      1                    NaT
# 887      10.0      True           1      1                    NaT
# 888      11.0      True           1      1                    NaT
# 889      12.0      True           1      1                    NaT
# 890      13.0      True           1      1                    NaT
# 891      14.0      True           1      1                    NaT
# 892      15.0      True           1      1                    NaT
# 893      16.0      True           1      1                    NaT
# 894      17.0      True           1      1 0 days 00:58:12.218000
# 895       1.0      True           1      2                    NaT
# 896       2.0      True           2      2                    NaT
# 897       3.0      True          24      2                    NaT
# 898       4.0      True           4      2                    NaT
# 899       5.0      True           4      2                    NaT
# 900       6.0      True           4      2                    NaT
# 901       7.0      True         245      2 0 days 01:27:17.699000

# %%
#De aqui solo queremos la temperatura de la pista, la temperatura ambiente y si llovía o no 
#Importante, hacemos match de la columna time, o ponemos simplemente el tiempo que hacia en la salida????
weather = weather.filter(['Time', 'AirTemp', 'Humidity', 'Rainfall', 'TrackTemp'])
weather
# Out:
#                       Time  AirTemp  Humidity  Rainfall  TrackTemp
# 0   0 days 00:00:33.270000     27.8      40.0     False       45.2
# 1   0 days 00:01:33.271000     28.0      39.0     False       45.1
# 2   0 days 00:02:33.287000     27.8      39.5     False       44.8
# 3   0 days 00:03:33.288000     27.5      40.4     False       44.3
# 4   0 days 00:04:33.288000     27.6      40.8     False       44.3
# ..                     ...      ...       ...       ...        ...
# 138 0 days 02:18:33.642000     27.8      41.9     False       36.2
# 139 0 days 02:19:33.642000     27.8      41.9     False       36.2
# 140 0 days 02:20:33.648000     27.7      41.9     False       36.2
# 141 0 days 02:21:33.643000     27.6      42.0     False       36.1
# 142 0 days 02:22:33.646000     27.6      42.3     False       35.8
#
# [143 rows x 5 columns]

# %%
weather['Time'] = weather['Time'].astype(str)
weather
# Out:
#                        Time  AirTemp  Humidity  Rainfall  TrackTemp
# 0    0 days 00:00:33.270000     27.8      40.0     False       45.2
# 1    0 days 00:01:33.271000     28.0      39.0     False       45.1
# 2    0 days 00:02:33.287000     27.8      39.5     False       44.8
# 3    0 days 00:03:33.288000     27.5      40.4     False       44.3
# 4    0 days 00:04:33.288000     27.6      40.8     False       44.3
# ..                      ...      ...       ...       ...        ...
# 138  0 days 02:18:33.642000     27.8      41.9     False       36.2
# 139  0 days 02:19:33.642000     27.8      41.9     False       36.2
# 140  0 days 02:20:33.648000     27.7      41.9     False       36.2
# 141  0 days 02:21:33.643000     27.6      42.0     False       36.1
# 142  0 days 02:22:33.646000     27.6      42.3     False       35.8
#
# [143 rows x 5 columns]

# %%
#Modificamos la columna de Time, para que solo nos muestre la hora y el minuto, esto es para
#que casen las keys al hacer el join y podamos tener info de la temperatura minuto a minuto en las vueltas
weather['Time'] = weather["Time"].apply(lambda x: x[7:12])
weather
# Out:
#       Time  AirTemp  Humidity  Rainfall  TrackTemp
# 0    00:00     27.8      40.0     False       45.2
# 1    00:01     28.0      39.0     False       45.1
# 2    00:02     27.8      39.5     False       44.8
# 3    00:03     27.5      40.4     False       44.3
# 4    00:04     27.6      40.8     False       44.3
# ..     ...      ...       ...       ...        ...
# 138  02:18     27.8      41.9     False       36.2
# 139  02:19     27.8      41.9     False       36.2
# 140  02:20     27.7      41.9     False       36.2
# 141  02:21     27.6      42.0     False       36.1
# 142  02:22     27.6      42.3     False       35.8
#
# [143 rows x 5 columns]

# %%
#Hacemos lo mismo para la columa Time de las vueltas
laps_race_pilot['Time'] = laps_race_pilot['Time'].astype(str)
laps_race_pilot['Time'] = laps_race_pilot["Time"].apply(lambda x: x[7:12])
laps_race_pilot
# Out:
#       Time                LapTime  LapNumber Compound  TyreLife FreshTyre  \
# 878  00:35                    NaT          1     SOFT       1.0      True
# 879  00:36 0 days 00:01:28.003000          2     SOFT       2.0      True
# 880  00:37 0 days 00:01:26.925000          3     SOFT       3.0      True
# 881  00:39 0 days 00:01:26.623000          4     SOFT       4.0      True
# 882  00:40 0 days 00:01:26.354000          5     SOFT       5.0      True
# 883  00:42 0 days 00:01:26.545000          6     SOFT       6.0      True
# 884  00:43 0 days 00:01:26.527000          7     SOFT       7.0      True
# 885  00:45 0 days 00:01:26.623000          8     SOFT       8.0      True
# 886  00:46 0 days 00:01:26.752000          9     SOFT       9.0      True
# 887  00:48 0 days 00:01:26.405000         10     SOFT      10.0      True
# 888  00:49 0 days 00:01:26.409000         11     SOFT      11.0      True
# 889  00:50 0 days 00:01:26.377000         12     SOFT      12.0      True
# 890  00:52 0 days 00:01:26.557000         13     SOFT      13.0      True
# 891  00:53 0 days 00:01:26.709000         14     SOFT      14.0      True
# 892  00:55 0 days 00:01:26.721000         15     SOFT      15.0      True
# 893  00:56 0 days 00:01:26.779000         16     SOFT      16.0      True
# 894  00:58 0 days 00:01:33.330000         17     SOFT      17.0      True
# 895  01:00 0 days 00:01:47.411000         18     HARD       1.0      True
# 896  01:01 0 days 00:01:26.026000         19     HARD       2.0      True
# 897  01:03 0 days 00:01:55.933000         20     HARD       3.0      True
# 898  01:05 0 days 00:01:57.406000         21     HARD       4.0      True
# 899  01:07 0 days 00:01:37.614000         22     HARD       5.0      True
# 900  01:08 0 days 00:01:55.578000         23     HARD       6.0      True
# 901  01:27                    NaT         24     HARD       7.0      True
#
#     TrackStatus  Stint              PitInTime
# 878           1      1                    NaT
# 879           1      1                    NaT
# 880           1      1                    NaT
# 881           1      1                    NaT
# 882           1      1                    NaT
# 883           1      1                    NaT
# 884           1      1                    NaT
# 885           2      1                    NaT
# 886           1      1                    NaT
# 887           1      1                    NaT
# 888           1      1                    NaT
# 889           1      1                    NaT
# 890           1      1                    NaT
# 891           1      1                    NaT
# 892           1      1                    NaT
# 893           1      1                    NaT
# 894           1      1 0 days 00:58:12.218000
# 895           1      2                    NaT
# 896           2      2                    NaT
# 897          24      2                    NaT
# 898           4      2                    NaT
# 899           4      2                    NaT
# 900           4      2                    NaT
# 901         245      2 0 days 01:27:17.699000

# %%
#Hacemos el join para meter en el mismo dataset, la imformacion en cada vuelta de la temperatura ambiente y de la pista

laps_race_pilot = laps_race_pilot.set_index('Time').join(weather.set_index('Time'))

# %%
laps_race_pilot['LapTime'] = laps_race_pilot['LapTime'].astype(str)
laps_race_pilot["LapTime"] = laps_race_pilot["LapTime"].apply(lambda x: x[10:19] if x!="NaT" else '0')
laps_race_pilot
# Out:
#          LapTime  LapNumber Compound  TyreLife FreshTyre TrackStatus  Stint  \
# Time
# 00:35          0          1     SOFT       1.0      True           1      1
# 00:36  01:28.003          2     SOFT       2.0      True           1      1
# 00:37  01:26.925          3     SOFT       3.0      True           1      1
# 00:39  01:26.623          4     SOFT       4.0      True           1      1
# 00:40  01:26.354          5     SOFT       5.0      True           1      1
# 00:42  01:26.545          6     SOFT       6.0      True           1      1
# 00:43  01:26.527          7     SOFT       7.0      True           1      1
# 00:45  01:26.623          8     SOFT       8.0      True           2      1
# 00:46  01:26.752          9     SOFT       9.0      True           1      1
# 00:48  01:26.405         10     SOFT      10.0      True           1      1
# 00:49  01:26.409         11     SOFT      11.0      True           1      1
# 00:50  01:26.377         12     SOFT      12.0      True           1      1
# 00:52  01:26.557         13     SOFT      13.0      True           1      1
# 00:53  01:26.709         14     SOFT      14.0      True           1      1
# 00:55  01:26.721         15     SOFT      15.0      True           1      1
# 00:56  01:26.779         16     SOFT      16.0      True           1      1
# 00:58  01:33.330         17     SOFT      17.0      True           1      1
# 01:00  01:47.411         18     HARD       1.0      True           1      2
# 01:01  01:26.026         19     HARD       2.0      True           2      2
# 01:03  01:55.933         20     HARD       3.0      True          24      2
# 01:05  01:57.406         21     HARD       4.0      True           4      2
# 01:07  01:37.614         22     HARD       5.0      True           4      2
# 01:08  01:55.578         23     HARD       6.0      True           4      2
# 01:27          0         24     HARD       7.0      True         245      2
#
#                    PitInTime  AirTemp  Humidity  Rainfall  TrackTemp
# Time
# 00:35                    NaT     27.6      41.6     False       43.9
# 00:36                    NaT     27.8      39.7     False       44.0
# 00:37                    NaT     27.9      39.9     False       44.2
# 00:39                    NaT     28.3      39.7     False       45.0
# 00:40                    NaT     28.0      40.0     False       44.7
# 00:42                    NaT     28.1      40.5     False       44.3
# 00:43                    NaT     28.2      39.9     False       43.9
# 00:45                    NaT     28.3      40.3     False       43.6
# 00:46                    NaT     28.2      41.0     False       43.7
# 00:48                    NaT     28.5      39.4     False       43.7
# 00:49                    NaT     27.9      40.8     False       43.7
# 00:50                    NaT     27.7      41.2     False       43.8
# 00:52                    NaT     28.2      40.3     False       44.2
# 00:53                    NaT     28.2      40.7     False       44.1
# 00:55                    NaT     27.9      40.6     False       43.5
# 00:56                    NaT     27.7      41.7     False       43.6
# 00:58 0 days 00:58:12.218000     27.8      41.2     False       44.2
# 01:00                    NaT     27.5      40.6     False       43.8
# 01:01                    NaT     27.5      41.2     False       43.6
# 01:03                    NaT     27.9      40.7     False       43.6
# 01:05                    NaT     27.8      40.6     False       43.9
# 01:07                    NaT     27.7      41.4     False       43.9
# 01:08                    NaT     28.1      40.4     False       43.7
# 01:27 0 days 01:27:17.699000     28.8      39.2     False       40.3

# %%
#Para la posicion de salida
#posicion_salida = race.get_driver(nombrePiloto)['GridPosition']
#posicion_salida
race.get_driver(nombrePiloto)
# Out:
# DriverNumber                  16
# BroadcastName          C LECLERC
# Abbreviation                 LEC
# TeamName                 Ferrari
# TeamColor                 DC0000
# FirstName                Charles
# LastName                 Leclerc
# FullName         Charles Leclerc
# Position                    18.0
# GridPosition                13.0
# Q1                           NaT
# Q2                           NaT
# Q3                           NaT
# Time                         NaT
# Status                  Accident
# Points                       0.0
# Name: Charles, dtype: object

# %%
#Necesitamos ahora los outputs, que es la siguiente vuelta a parar
vueltas_parada = laps_race_pilot[laps_race_pilot['PitInTime'].notna()]
vueltas_parada
# Out:
#          LapTime  LapNumber Compound  TyreLife FreshTyre TrackStatus  Stint  \
# Time
# 00:58  01:33.330         17     SOFT      17.0      True           1      1
# 01:27          0         24     HARD       7.0      True         245      2
#
#                    PitInTime  AirTemp  Humidity  Rainfall  TrackTemp
# Time
# 00:58 0 days 00:58:12.218000     27.8      41.2     False       44.2
# 01:27 0 days 01:27:17.699000     28.8      39.2     False       40.3

# %%
nVuelta_parada = vueltas_parada['LapNumber']
nParadas = 0
paradas = []
for i in nVuelta_parada:
    paradas.append(i)
    nParadas = nParadas + 1


print("El numero de paradas ha sido: ", nParadas)

print("Las paradas han sido en las vueltas: ", paradas)
# Out:
# El numero de paradas ha sido:  2
# Las paradas han sido en las vueltas:  [17, 24]

# %%
#Eliminanos la variable de la hora a la que entra a box porque ya no es necesaria
laps_race_pilot.drop(['PitInTime'], axis = 1, inplace=True)
#laps_race_pilot.drop(laps_race_pilot[(laps_race_pilot['LapTime'] =='0') & (laps_race_pilot['LapNumber'] != 1)].index, inplace=True)
laps_race_pilot
# Out:
#          LapTime  LapNumber Compound  TyreLife FreshTyre TrackStatus  Stint  \
# Time
# 00:35          0          1     SOFT       1.0      True           1      1
# 00:36  01:28.003          2     SOFT       2.0      True           1      1
# 00:37  01:26.925          3     SOFT       3.0      True           1      1
# 00:39  01:26.623          4     SOFT       4.0      True           1      1
# 00:40  01:26.354          5     SOFT       5.0      True           1      1
# 00:42  01:26.545          6     SOFT       6.0      True           1      1
# 00:43  01:26.527          7     SOFT       7.0      True           1      1
# 00:45  01:26.623          8     SOFT       8.0      True           2      1
# 00:46  01:26.752          9     SOFT       9.0      True           1      1
# 00:48  01:26.405         10     SOFT      10.0      True           1      1
# 00:49  01:26.409         11     SOFT      11.0      True           1      1
# 00:50  01:26.377         12     SOFT      12.0      True           1      1
# 00:52  01:26.557         13     SOFT      13.0      True           1      1
# 00:53  01:26.709         14     SOFT      14.0      True           1      1
# 00:55  01:26.721         15     SOFT      15.0      True           1      1
# 00:56  01:26.779         16     SOFT      16.0      True           1      1
# 00:58  01:33.330         17     SOFT      17.0      True           1      1
# 01:00  01:47.411         18     HARD       1.0      True           1      2
# 01:01  01:26.026         19     HARD       2.0      True           2      2
# 01:03  01:55.933         20     HARD       3.0      True          24      2
# 01:05  01:57.406         21     HARD       4.0      True           4      2
# 01:07  01:37.614         22     HARD       5.0      True           4      2
# 01:08  01:55.578         23     HARD       6.0      True           4      2
# 01:27          0         24     HARD       7.0      True         245      2
#
#        AirTemp  Humidity  Rainfall  TrackTemp
# Time
# 00:35     27.6      41.6     False       43.9
# 00:36     27.8      39.7     False       44.0
# 00:37     27.9      39.9     False       44.2
# 00:39     28.3      39.7     False       45.0
# 00:40     28.0      40.0     False       44.7
# 00:42     28.1      40.5     False       44.3
# 00:43     28.2      39.9     False       43.9
# 00:45     28.3      40.3     False       43.6
# 00:46     28.2      41.0     False       43.7
# 00:48     28.5      39.4     False       43.7
# 00:49     27.9      40.8     False       43.7
# 00:50     27.7      41.2     False       43.8
# 00:52     28.2      40.3     False       44.2
# 00:53     28.2      40.7     False       44.1
# 00:55     27.9      40.6     False       43.5
# 00:56     27.7      41.7     False       43.6
# 00:58     27.8      41.2     False       44.2
# 01:00     27.5      40.6     False       43.8
# 01:01     27.5      41.2     False       43.6
# 01:03     27.9      40.7     False       43.6
# 01:05     27.8      40.6     False       43.9
# 01:07     27.7      41.4     False       43.9
# 01:08     28.1      40.4     False       43.7
# 01:27     28.8      39.2     False       40.3

# %%
nVueltasDadas = int(laps_race_pilot.tail(1)['LapNumber'].iloc[0])
nVueltasDadas
# Out:
# 24

# %%
#Ahora hay que añadir al dataframe las variables
# - Posicion de salida
# - Siguiente parada (dependera de la vuelta en la que se encuentre)
# - Todas variables del circuito en el que nos encontramos, en este caso Barcelona
# - No creo que haga falta el piloto, las estrategias son independientes del piloto (o eso voy a pensar... que no será asi)
circuito_actual = circuitos_desgaste.loc[circuitos_desgaste['Location/country'].str.lower() == nombreCircuito.lower()]
circuito_actual = circuito_actual.filter(['circuitName', 'desgaste', 'vueltas_totales', 'km_total'])
circuito_actual
vueltasOficialesCircuito = circuito_actual['vueltas_totales'].iloc[0]
print(vueltasOficialesCircuito)
print(nVueltasDadas)
disminuido = False

if (str(nVueltasDadas) == vueltasOficialesCircuito):
    nVueltasDadas = nVueltasDadas -1
    disminuido = True

print("Las vueltas son: " + str(nVueltasDadas))
# Out:
# 63
# 24
# Las vueltas son: 24

# %%
#Ahora hay que introducir la columna posicionActual que es la posicion que ocupa un piloto por cada paso por meta3#
#para cada una de las vueltas que un piloto dio en un determinado gran premio
#Para elllo hay que construir la llamada a la API de Ergast, que tiene esta pinta:
# http://ergast.com/api/f1/2022/1/drivers/alonso/laps/19
#Necesitamos el numero de ronda, el año del gp, el numero de vuelta y el nombre del piloto
import requests
import json
import time
roundNumber = race.event.RoundNumber
pilotoNombre=pilotosDic[nombrePiloto]
posicionesList = []
pilotoDelanteList = []
tiempoPilotoDelanteList = []
pilotoDetrasList = []
tiempoPilotoDetrasList = []


#Llamada a api de posiciones
api = "http://ergast.com/api/f1/" + str(anyoGp) + "/" + str(roundNumber) + "/drivers/" +pilotoNombre + "/laps.json?limit=100"
response = requests.get(api)
posiciones_dict = json.loads(response.text)
#Llamada a api de pilotos y tiempo
api = "http://ergast.com/api/f1/" + str(anyoGp) + "/" + str(roundNumber) + "/" + "laps.json?limit=4000"
response = requests.get(api)
pilotos_dict = json.loads(response.text)
    
#El numero de vuelta es una iteracion a cada fila dell dataframe de vueltas del piloto

for nVuelta in range (0, nVueltasDadas):
    print(nVuelta, nVueltasDadas)
    #Para la posicion por cada vuelta
    posicion = posiciones_dict['MRData']['RaceTable']['Races'][0]['Laps'][nVuelta]['Timings'][0]['position']
    posicionesList.append(posicion)

    #Para el piloto de delante y su tiempo en cada vuelta
    pilotoDelante = pilotos_dict['MRData']['RaceTable']['Races'][0]['Laps'][nVuelta]['Timings'][int(posicion)-2]['driverId']
    tiempoPilotoDelante = pilotos_dict['MRData']['RaceTable']['Races'][0]['Laps'][nVuelta]['Timings'][int(posicion)-2]['time']
    pilotoDelanteList.append(pilotoDelante)
    tiempoPilotoDelanteList.append(tiempoPilotoDelante)
    print("Voy el: ", posicion)  
    print("Tengo delante a : ", pilotoDelante)  

    #Para el piloto de detras y su tiempo en cada vuelta
    pilotoDetras = pilotos_dict['MRData']['RaceTable']['Races'][0]['Laps'][nVuelta]['Timings'][int(posicion)]['driverId']
    tiempoPilotoDetras = pilotos_dict['MRData']['RaceTable']['Races'][0]['Laps'][nVuelta]['Timings'][int(posicion)]['time']
    pilotoDetrasList.append(pilotoDetras)
    tiempoPilotoDetrasList.append(tiempoPilotoDetras)  
    print("Tengo detras a : ", pilotoDetras)  



if (disminuido):
    posicionesList.append("NaN")
    pilotoDelanteList.append("NaN")
    tiempoPilotoDelanteList.append("NaN")
    pilotoDetrasList.append("NaN")
    tiempoPilotoDetrasList.append("NaN")

laps_race_pilot['posicionActual'] = posicionesList
laps_race_pilot['pilotoDelante'] = pilotoDelanteList
laps_race_pilot['tiempoPilotoDelante'] = tiempoPilotoDelanteList
laps_race_pilot['pilotoDetras'] = pilotoDetrasList
laps_race_pilot['tiempoPilotoDetras'] = tiempoPilotoDetrasList

laps_race_pilot
# Out:
# 0 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  giovinazzi
# 1 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  giovinazzi
# 2 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  giovinazzi
# 3 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 4 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 5 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 6 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 7 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 8 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 9 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 10 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 11 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 12 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 13 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 14 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 15 24
# Voy el:  13
# Tengo delante a :  raikkonen
# Tengo detras a :  albon
# 16 24
# Voy el:  16
# Tengo delante a :  grosjean
# Tengo detras a :  russell
# 17 24
# Voy el:  17
# Tengo delante a :  russell
# Tengo detras a :  latifi
# 18 24
# Voy el:  17
# Tengo delante a :  raikkonen
# Tengo detras a :  latifi
# 19 24
# Voy el:  17
# Tengo delante a :  raikkonen
# Tengo detras a :  latifi
# 20 24
# Voy el:  17
# Tengo delante a :  raikkonen
# Tengo detras a :  latifi
# 21 24
# Voy el:  14
# Tengo delante a :  kvyat
# Tengo detras a :  albon
# 22 24
# Voy el:  6
# Tengo delante a :  raikkonen
# Tengo detras a :  latifi
# 23 24
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[290], line 32
#      30 print(nVuelta, nVueltasDadas)
#      31 #Para la posicion por cada vuelta
# ---> 32 posicion = posiciones_dict['MRData']['RaceTable']['Races'][0]['Laps'][nVuelta]['Timings'][0]['position']
#      33 posicionesList.append(posicion)
#      35 #Para el piloto de delante y su tiempo en cada vuelta
#
# IndexError: list index out of range

# %%
roundNumber
# Out:
# 8

# %%
#Hay que hacer una funcion para sacar el numero de vueltas (nVueltas) que se ha dado en ese circuito, y repetir nVueltas para crear una lista con el valor
nVueltasCircuito=laps_race_pilot.tail(1).LapNumber.values[0]
circuitName = circuito_actual.circuitName.values[0]
desgaste = circuito_actual.desgaste.values[0]
km_total = circuito_actual.km_total.values[0]
vueltas_totales = circuito_actual.vueltas_totales.values[0]
desgaste
print(nVueltasCircuito)
# Out:
# 23

# %%
posicion_salida = race.get_driver(nombrePiloto)['GridPosition']

#La salida se la tenemos que meter a todas las filas del dataframe
laps_race_pilot['posicionSalida'] = posicion_salida
#laps_race_pilot['circuitName'] = circuitName
#laps_race_pilot['desgasteCircuito'] = desgaste
#laps_race_pilot['vueltasCircuito'] = vueltas_totales
#laps_race_pilot['kmCircuitoTotales'] = km_total

laps_race_pilot
# Out:
#          LapTime  LapNumber Compound  TyreLife FreshTyre TrackStatus  Stint  \
# Time
# 00:35          0          1     SOFT       1.0      True           1      1
# 00:36  01:28.003          2     SOFT       2.0      True           1      1
# 00:37  01:26.925          3     SOFT       3.0      True           1      1
# 00:39  01:26.623          4     SOFT       4.0      True           1      1
# 00:40  01:26.354          5     SOFT       5.0      True           1      1
# 00:42  01:26.545          6     SOFT       6.0      True           1      1
# 00:43  01:26.527          7     SOFT       7.0      True           1      1
# 00:45  01:26.623          8     SOFT       8.0      True           2      1
# 00:46  01:26.752          9     SOFT       9.0      True           1      1
# 00:48  01:26.405         10     SOFT      10.0      True           1      1
# 00:49  01:26.409         11     SOFT      11.0      True           1      1
# 01:00            1:26.498       latifi           1:26.132            13.0
# 01:01            1:46.392       latifi           1:26.418            13.0
# 01:03            1:54.667       latifi           1:59.685            13.0
# 01:05            1:58.974       latifi           1:46.240            13.0
# 01:07            2:14.530        albon           2:12.273            13.0
# 01:08            1:55.684       latifi           1:55.314            13.0

# %%
#Ahora hay que meter las paradas, habria que añadir una columna con la siguiente parada, dependiendo de la vuelta en la que se encuentre
paradas_list = paradas
paradas_list
# Out:
# [17, 24]

# %%
#En cada intervalo de ventana de parada, se añade la siguiente parada de acuerdo con el numero de vuelta en el que vamos
#Es decir, del intervalo 1-9, el valor de la siguiente parada es 10, del 10-30, el valor es 31, y así
#NOTA: Cuando se hace la ultima parada, ¿cual debe ser el valor del la siguiente parada? ¿El numero de fin de vuelta?


inserciones = 1
paradasList_insertar = []
for i in paradas_list:
        while (inserciones <= i):
            paradasList_insertar.append(i)
            inserciones = inserciones + 1
            if (inserciones == paradas_list[nParadas-1]):
                while inserciones < nVueltasCircuito:
                    paradasList_insertar.append(nVueltasCircuito)
                    inserciones = inserciones + 1
paradasList_insertar
len(paradasList_insertar)
# Out:
# 24

# %%
#Insertamos la nueva columna
laps_race_pilot['nextPit'] = paradasList_insertar
laps_race_pilot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[266], line 2
#       1 #Insertamos la nueva columna
# ----> 2 laps_race_pilot['nextPit'] = paradasList_insertar
#       3 laps_race_pilot
#
# File /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File /usr/local/lib/python3.8/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (24) does not match length of index (23)

# %% [markdown]
# En principio, ahora tenemos el dataset para:
#
# - Un piloto
# - En un gran premio
# - Durante todas sus vueltas

# %%
laps_race_pilot.to_csv("../datasets_completos/laps_" + nombreCircuito + "_" + nombrePiloto  +"_" +str(anyoGp)+ ".csv", index=False)
